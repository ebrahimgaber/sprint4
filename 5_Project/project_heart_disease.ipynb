# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import csv
from pathlib import Path

# we want our plots to appear inside the notebook
# %matplotlib inline

# Models from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# Model Evaluations
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve

df = pd.read_csv("D:\M_learning\sprint4\heart.csv")

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# 5   0     2       1
# 6   3     1       0
# 7   1     3       0
# 8   0     3       0
# 9   2     2       0

# %%
df.tail()
# Out:
#       age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    male   1       140   221    0        1      164      1      0.0
# 1021   60    male   0       125   258    0        0      141      1      2.8
# 1022   47    male   0       110   275    0        0      118      1      1.0
# 1023   50  female   0       110   254    0        0      159      0      0.0
# 1024   54    male   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal target
# 1020      2   0     2    NaN
# 1021      1   1     3    NaN
# 1022      1   1     2    NaN
# 1023      2   0     2    NaN
# 1024      1   1     3    NaN

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_a08d3_row0_col0, #T_a08d3_row1_col1, #T_a08d3_row2_col2, #T_a08d3_row3_col3, #T_a08d3_row4_col4, #T_a08d3_row5_col5, #T_a08d3_row6_col6, #T_a08d3_row7_col7, #T_a08d3_row8_col8, #T_a08d3_row9_col9, #T_a08d3_row10_col10, #T_a08d3_row11_col11, #T_a08d3_row12_col12, #T_a08d3_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a08d3_row0_col1, #T_a08d3_row8_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_a08d3_row0_col2, #T_a08d3_row4_col13, #T_a08d3_row6_col12 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_a08d3_row0_col3 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_a08d3_row0_col4, #T_a08d3_row1_col10, #T_a08d3_row4_col8 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a08d3_row0_col5, #T_a08d3_row1_col0, #T_a08d3_row10_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_a08d3_row0_col6, #T_a08d3_row6_col3, #T_a08d3_row10_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a08d3_row0_col7, #T_a08d3_row1_col4, #T_a08d3_row4_col6, #T_a08d3_row6_col5, #T_a08d3_row7_col0, #T_a08d3_row8_col2, #T_a08d3_row8_col13, #T_a08d3_row9_col10, #T_a08d3_row9_col13, #T_a08d3_row10_col9, #T_a08d3_row13_col1, #T_a08d3_row13_col3, #T_a08d3_row13_col8, #T_a08d3_row13_col11, #T_a08d3_row13_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a08d3_row0_col8, #T_a08d3_row11_col12 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_a08d3_row0_col9 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_a08d3_row0_col10, #T_a08d3_row1_col2, #T_a08d3_row2_col9 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_a08d3_row0_col11, #T_a08d3_row3_col0, #T_a08d3_row11_col0 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_a08d3_row0_col12, #T_a08d3_row11_col1, #T_a08d3_row12_col10 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_a08d3_row0_col13, #T_a08d3_row2_col11, #T_a08d3_row7_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a08d3_row1_col3, #T_a08d3_row12_col5, #T_a08d3_row13_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a08d3_row1_col5, #T_a08d3_row4_col5, #T_a08d3_row10_col8 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_a08d3_row1_col6, #T_a08d3_row13_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a08d3_row1_col7, #T_a08d3_row13_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_a08d3_row1_col8, #T_a08d3_row1_col12, #T_a08d3_row8_col12 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_a08d3_row1_col9, #T_a08d3_row6_col10 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_a08d3_row1_col11, #T_a08d3_row4_col10 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_a08d3_row1_col13, #T_a08d3_row12_col6 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_a08d3_row2_col0, #T_a08d3_row4_col2, #T_a08d3_row11_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_a08d3_row2_col1, #T_a08d3_row6_col0 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T
xesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'ca'}>],
#        [<AxesSubplot:title={'center':'thal'}>,
#         <AxesSubplot:title={'center':'target'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.boxplot(x=df['chol'])
# Out:
# <AxesSubplot:xlabel='fbs'>

# %%
sns.boxplot(x=df['cp'])
# Out:
# <AxesSubplot:xlabel='cp'>

# %%
sns.boxplot(x=df['ca'])
# Out:
# <AxesSubplot:xlabel='ca'>

# %%
colCAT = []
colNUM = []
for i in df.columns:
    if (len(df[i].unique())) > 5:
        colNUM.append(i)
    else:
        colCAT.append(i)
    print('unique values:  {}\t{}'.format(len(df[i].unique()),i))

dfCAT = df[colCAT]     
colNUM.append('target')  

dfNUM = df[colNUM]
# Out:
# unique values:  41	age
# unique values:  2	sex
# unique values:  4	cp
# unique values:  49	trestbps
# unique values:  152	chol
# unique values:  2	fbs
# unique values:  3	restecg
# unique values:  91	thalach
# unique values:  2	exang
# unique values:  40	oldpeak
# unique values:  3	slope
# unique values:  5	ca
# unique values:  4	thal
# unique values:  1	target

# %%
print(df.columns.tolist())
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
df['sex'] = df['sex'].map({0:'female', 1:'male'})
df['target'] = df['target'].map({0:'no disease', 1:'disease'})

# %%
dataCAT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sex      1025 non-null   int64
#  1   cp       1025 non-null   int64
#  2   fbs      1025 non-null   int64
#  3   restecg  1025 non-null   int64
#  4   exang    1025 non-null   int64
#  5   slope    1025 non-null   int64
#  6   ca       1025 non-null   int64
#  7   thal     1025 non-null   int64
#  8   target   1025 non-null   int64
# dtypes: int64(9)
# memory usage: 72.2 KB

# %%
dataCAT.head()
# Out:
#    sex  cp  fbs  restecg  exang  slope  ca  thal  target
# 0    1   0    0        1      0      2   2     3       0
# 1    1   0    1        0      1      0   0     3       0
# 2    1   0    0        1      1      0   0     3       0
# 3    1   0    0        1      0      2   1     3       0
# 4    0   0    1        1      0      1   3     2       0

# %%
df.isna().sum()
# Out:
# age            0
# sex            0
# cp             0
# trestbps       0
# chol           0
# fbs            0
# restecg        0
# thalach        0
# exang          0
# oldpeak        0
# slope          0
# ca             0
# thal           0
# target      1025
# dtype: int64

# %%
dataCAT["target"].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
dataCAT["target"].value_counts().plot(kind="bar", color=["salmon", "lightblue"])
# Out:
# <AxesSubplot:>

# %%
dataCorr = df.corr()
plt.figure(figsize=(20,20))
plt.title('Heart Disease - CORRELATION, Overall', fontsize=14)
sns.heatmap(dataCorr, annot=True, fmt='.2f', square=True, cmap = 'Blues_r')
# Out:
# <AxesSubplot:title={'center':'Heart Disease - CORRELATION, Overall'}>

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['target'], axis = 1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Train set:  ', X_train.shape,  y_train.shape)
print ('Test set:   ', X_test.shape,  y_test.shape)
# Out:
# Train set:   (820, 13) (820,)
# Test set:    (205, 13) (205,)
